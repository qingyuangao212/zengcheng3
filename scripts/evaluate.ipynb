# %%
import os
os.chdir('/data2/qingyuan/projects/zengcheng3')

# %%
import os
import pandas as pd
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.monitor import Monitor

from reev_control.envs import SimpleVehicleEnv2, SimpleVehicleEnv3
from reev_control.envs.wrappers import ActionFlatteningWrapper, InfoSumWrapper
from reev_control.custom_ppo import CustomPPO  # your CustomPPO
import torch
import yaml

# --- Settings ---
folder = "train_results/wandb/offline-run-20250603_171003-2v1jr8zy/files"
model_path = f"{folder}/model.zip"
vecnorm_path = f"{folder}/vec_env.pkl"  # adjust path

# load wandb config from train folder
with open(f'{folder}/config.yaml', 'r') as file:
    train_config = yaml.safe_load(file)

train_config = {
    k: v["value"]
    for k, v in train_config.items()
    if (isinstance(v, dict) and "value" in v and k!='_wandb')
}

train_config['file_list_file'] = "data/train/Mar2025_filtered_files.pkl"  # path to file list


# obs_keys_to_log = ["some_obs_name1", "some_obs_name2"]  # update based on your actual obs
# info_keys_to_log = ["nvh_reward_sum", "efficiency_reward_sum", "step_soc_reward_sum", "end_soc_reward"]  # update accordingly

# --- Create single environment for inference ---
def make_eval_env(seed: int = 0, **kwargs):

    def _init():

        env = SimpleVehicleEnv2(
            data_folder='data/train/REEV07RearDrive_Mar2025',
            seed=seed, **kwargs)
        # env.reset()
        return env

    return _init

env = DummyVecEnv([make_eval_env(**train_config)])




# --- Load VecNormalize ---
env = VecNormalize.load(vecnorm_path, env)
env.training = False
env.norm_reward = False     # want original reward in eval

# %%
env.action_space
# Out:
# Box(3.0, 100.0, (1,), float32)

# %%
env.envs[0].trajectory_loader.file_list_files
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 env.envs[0].trajectory_loader.file_list_files
#
# AttributeError: 'TrajectoryLoader' object has no attribute 'file_list_files'

# %%
import yaml

# Load from file
with open('/data2/qingyuan/projects/zengcheng3/train_results/wandb/offline-run-20250603_171003-2v1jr8zy/files/config.yaml', 'r') as file:
    data = yaml.safe_load(file)

config = {
    k: v["value"]
    for k, v in data.items()
    if (isinstance(v, dict) and "value" in v and k!='_wandb')
}

# %%
config
# Out:
# {'env_class': 'SimpleVehicleEnv2',
#  'config_path': 'reev_control/envs/config.yaml',
#  'obs_seq_len': 1800,
#  'data_start_index': 600,
#  'data_min_length': 3600,
#  'step_size_in_seconds': 30,
#  'reward_weights': [0.01, 200, 0.001, 0.05],
#  'n_envs': 16,
#  'policy_type': 'MlpPolicy',
#  'total_timesteps': 50000000,
#  'n_steps': 1024,
#  'batch_size': 512,
#  'n_epochs': 10,
#  'gamma': 0.99,
#  'learning_rate': 0.0003,
#  'ent_coef': 0.01,
#  'vf_coef': 0.5,
#  'device': 'cpu'}

# %%
data['_wandb']
# Out:
# {'desc': None,
#  'value': {'code_path': 'code/scripts/sb3_ppo_train.py',
#   'python_version': '3.12.7',
#   'cli_version': '0.19.9',
#   'framework': 'torch',
#   'is_jupyter_run': False,
#   'is_kaggle_kernel': False,
#   'start_time': 1748941803,
#   't': {1: [1, 55],
#    3: [4, 13, 16, 23, 35, 42, 55],
#    4: '3.12.7',
#    5: '0.19.9',
#    8: [5],
#    13: 'linux-x86_64'}}}

# %%
import numpy as np

np.nansum([np.nan, np.nan])
# Out:
# np.float64(0.0)

# %%
from stable_baselines3.common.utils import safe_mean
0([np.nan, np.nan, 1])
# Out:
# nan
